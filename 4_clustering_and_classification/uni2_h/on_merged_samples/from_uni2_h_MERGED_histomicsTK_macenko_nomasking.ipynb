# %% [markdown]
# Clustering and classification for features extracted from tiles modified with StainNet.

# %% [markdown]
# ---
# # 0. - Imports and paths

# %%
import os
import pandas as pd
import matplotlib.font_manager as fm
# %matplotlib inline
import matplotlib.pyplot as plt
import pickle
import matplotlib.image as mpimg
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import seaborn as sns
from PIL import Image, ImageDraw
import numpy as np
import re
from collections import defaultdict
import matplotlib.pyplot as plt
from sklearn.cluster import FeatureAgglomeration
from sklearn.decomposition import PCA#, TruncatedSVD
#import umap
import umap.umap_ as umap
from sklearn.manifold import TSNE
from matplotlib.lines import Line2D

# %%
os.chdir("/disk2/user/gabgam/work/gigi_env/the_project/4_clustering_and_classification/")
print(os.getcwd())
# Out:
# /disk2/work/gabgam/gigi_env/the_project/4_clustering_and_classification

# %%
# Fetch DM Sans font file from https://github.com/google/fonts/blob/main/ofl/dmsans/DMSans%5Bopsz%2Cwght%5D.ttf or, better, https://fonts.google.com/specimen/DM+Sans
font_path = "../fonts/static/DMSans-Medium.ttf" 

# Add font to matplotlib
try:
    fm.fontManager.addfont(font_path)
    plt.rcParams['font.family'] = 'DM Sans'
except RuntimeError as e:
    print(f"Failed to load font: {e}")

# %%
model = "UNI2-h"

# %%
PATH_TO_MERGED_PICKLES = f"output/{model}/satac_C1_v3_allspots_&_visium_2022_FF_WG_10X_img_not_changed_allspots/"
COMPARISON = "satac_C1_v3_allspots_&_visium_2022_FF_WG_10X_img_not_changed_allspots"

SELECTED_PICKLE_100um = 'MERGED_satac_C1_&_v3_allspots__&__visium_2022_FF_WG_10X_&_img_not_changed_allspots__for__target_is_reference_full_100um_histomicsTK_macenko_nomasking.pickle'
SELECTED_PICKLE_68um = 'MERGED_satac_C1_&_v3_allspots__&__visium_2022_FF_WG_10X_&_img_not_changed_allspots__for__target_is_reference_full_68um_histomicsTK_macenko_nomasking.pickle'

# %%
# PATH_TO_MERGED_PICKLES = f"output/{model}/satac_C1_v3_allspots_&_visium_FFPE_dcis_idc_10X_img_not_changed_allspots/"
# COMPARISON = "satac_C1_v3_allspots_&_visium_FFPE_dcis_idc_10X_img_not_changed_allspots"

# SELECTED_PICKLE_100um = 'MERGED_satac_C1_&_v3_allspots__&__visium_FFPE_dcis_idc_10X_&_img_not_changed_allspots__for__target_is_reference_full_100um_histomicsTK_macenko_nomasking.pickle'
# SELECTED_PICKLE_68um = 'MERGED_satac_C1_&_v3_allspots__&__visium_FFPE_dcis_idc_10X_&_img_not_changed_allspots__for__target_is_reference_full_68um_histomicsTK_macenko_nomasking.pickle'

# %%
# path to the target image
PATH_TO_REFERENCE = "../2_image_normalisation/reference_images/reference_full.jpeg"
# `TARGET_IS_<filename>`
TARGET_IS = "target_is_reference_full"

# %% [markdown]
# Defining the path to the figures.

# %%
PATH_TO_FIGURES = f"figures/{model}/{COMPARISON}"
os.makedirs(PATH_TO_FIGURES, exist_ok=True)

# %% [markdown]
# # 1. - Importing the extracted features

# %% [markdown]
# First of all, let's see all the MERGED `.pickle` files inside the folder of the saved features.

# %%
all_pickle_names = [i for i in os.listdir(PATH_TO_MERGED_PICKLES) if i.endswith('.pickle')]

print(f"{len(all_pickle_names)} .pickle files inside the folder.\n")
print(all_pickle_names)
# Out:
# 8 .pickle files inside the folder.
#
# ['MERGED_satac_C1_&_v3_allspots__&__visium_2022_FF_WG_10X_&_img_not_changed_allspots__for__target_is_reference_full_100um_ORIGINAL WSI.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_2022_FF_WG_10X_&_img_not_changed_allspots__for__target_is_reference_full_100um_fromWSI_histomicsTK_macenko_nomasking.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_2022_FF_WG_10X_&_img_not_changed_allspots__for__target_is_reference_full_100um_histomicsTK_macenko_nomasking.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_2022_FF_WG_10X_&_img_not_changed_allspots__for__target_is_reference_full_100um_stainNET.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_2022_FF_WG_10X_&_img_not_changed_allspots__for__target_is_reference_full_68um_ORIGINAL WSI.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_2022_FF_WG_10X_&_img_not_changed_allspots__for__target_is_reference_full_68um_fromWSI_histomicsTK_macenko_nomasking.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_2022_FF_WG_10X_&_img_not_changed_allspots__for__target_is_reference_full_68um_histomicsTK_macenko_nomasking.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_2022_FF_WG_10X_&_img_not_changed_allspots__for__target_is_reference_full_68um_stainNET.pickle']

# %% [markdown]
# And let's choose the first file to visualise and extract the normalisation name from it.

# %%
TILE_SIZE = 100
SPOT_SIZE = 68

# Extractin the normalisation name from just one of it. They are the same in the end
# Find the pattern matching "<number>um_", the normalisation name is after it.
match = re.search(r"\d+um_", SELECTED_PICKLE_100um)

if match:
    # Extract everything after "<number>um_", remove the file type name and replace eventually present underscores with spaces.
    normalisation_name = SELECTED_PICKLE_100um.split(match.group())[-1].split(".")[0].replace("_", " ")
else:
    print("Wrong file inserted, no normalisation name found.")

print(normalisation_name)
# Out:
# histomicsTK macenko nomasking

# %%
from utils_clust_n_class import load_pickle_as_df

merged_selected_pickle_df_100um = load_pickle_as_df(os.path.join(PATH_TO_MERGED_PICKLES, SELECTED_PICKLE_100um))
merged_selected_pickle_df_100um
# Out:
#                                                         0         1     \
# TTATTTCCAGTATCTT_row6_col18_100um_histomicsTK_m...  0.124812  0.456939
# TCAAATCACCATTGTT_row7_col19_100um_histomicsTK_m...  0.254652  0.281422
# CTGTAAGTCTTCTGCT_row6_col20_100um_histomicsTK_m... -0.011986  0.514269
# ACATCCGACTTTGGGT_row7_col21_100um_histomicsTK_m...  0.331965  0.732342
# TGATAGATGCCCTGTT_row6_col22_100um_histomicsTK_m... -0.294759  0.029385
# ...                                                      ...       ...
# GAACGTTTGTATCCAC-1_row77_col123_100um_histomics... -0.239360 -0.085375
# ATTGAATTCCCTGTAG-1_row76_col124_100um_histomics... -0.438314 -0.272793
# TACCTCACCAATTGTA-1_row77_col125_100um_histomics...  0.310214 -0.128880
# AGTCGAATTAGCGTAA-1_row76_col126_100um_histomics... -0.074272 -0.433240
# TTGAAGTGCATCTACA-1_row77_col127_100um_histomics... -0.194547 -0.329518
#
#                                                         2         3     \
# TTATTTCCAGTATCTT_row6_col18_100um_histomicsTK_m...  0.355705 -0.028777
# TCAAATCACCATTGTT_row7_col19_100um_histomicsTK_m... -0.282730  0.020829
# CTGTAAGTCTTCTGCT_row6_col20_100um_histomicsTK_m... -0.151397 -0.086166
# ACATCCGACTTTGGGT_row7_col21_100um_histomicsTK_m... -0.005193  0.018344
# TGATAGATGCCCTGTT_row6_col22_100um_histomicsTK_m...  0.155710 -0.243489
# ...                                                      ...       ...
# GAACGTTTGTATCCAC-1_row77_col123_100um_histomics... -0.276265 -0.307827
# ATTGAATTCCCTGTAG-1_row76_col124_100um_histomics... -0.017341 -0.425316
# TACCTCACCAATTGTA-1_row77_col125_100um_histomics... -0.249115 -0.363930
# AGTCGAATTAGCGTAA-1_row76_col126_100um_histomics... -0.472722 -0.468590
# TTGAAGTGCATCTACA-1_row77_col127_100um_histomics...  0.163445 -0.409504
#
#                                                         4         5     \
# TTATTTCCAGTATCTT_row6_col18_100um_histomicsTK_m...  0.003545 -0.443926
# TCAAATCACCATTGTT_row7_col19_100um_histomicsTK_m...  0.009576 -0.282667
# CTGTAAGTCTTCTGCT_row6_col20_100um_histomicsTK_m...  0.137472 -0.204235
# ACATCCGACTTTGGGT_row7_col21_100um_histomicsTK_m... -0.102333 -0.537718
# TGATAGATGCCCTGTT_row6_col22_100um_histomicsTK_m...  0.130776 -0.079380
# ...                                                      ...       ...
# GAACGTTTGTATCCAC-1_row77_col123_100um_histomics... -0
# TTGAAGTGCATCTACA-1_row77_col127_68um_histomicsT... -0.086724  0.039290
#
#                                                         6         7     \
# CCGACCACCCTACGCG_row0_col0_68um_histomicsTK_mac...  0.191508 -0.812966
# AAGCCATAGTCGCGAC_row1_col1_68um_histomicsTK_mac... -0.105391 -0.485860
# TTGGGCGGACCGAAGC_row0_col2_68um_histomicsTK_mac... -0.055894 -0.534804
# AGTAAAGCGCATAATC_row1_col3_68um_histomicsTK_mac... -0.056769 -0.698137
# CGACTCCGCCGATCAA_row0_col4_68um_histomicsTK_mac... -0.077091 -0.503361
# ...                                                      ...       ...
# GAACGTTTGTATCCAC-1_row77_col123_68um_histomicsT...  0.331185 -0.333182
# ATTGAATTCCCTGTAG-1_row76_col124_68um_histomicsT...  0.131953 -0.094733
# TACCTCACCAATTGTA-1_row77_col125_68um_histomicsT...  0.167783 -0.130470
# AGTCGAATTAGCGTAA-1_row76_col126_68um_histomicsT... -0.029078 -0.070886
# TTGAAGTGCATCTACA-1_row77_col127_68um_histomicsT... -0.060044 -0.154023
#
#                                                         8         9     ...  \
# CCGACCACCCTACGCG_row0_col0_68um_histomicsTK_mac...  0.297080  0.237753  ...
# AAGCCATAGTCGCGAC_row1_col1_68um_histomicsTK_mac...  0.087259  0.430128  ...
# TTGGGCGGACCGAAGC_row0_col2_68um_histomicsTK_mac...  0.257114  0.336024  ...
# AGTAAAGCGCATAATC_row1_col3_68um_histomicsTK_mac...  0.241743  0.195445  ...
# CGACTCCGCCGATCAA_row0_col4_68um_histomicsTK_mac...  0.096658  0.541754  ...
# ...                                                      ...       ...  ...
# GAACGTTTGTATCCAC-1_row77_col123_68um_histomicsT... -0.441195  0.165890  ...
# ATTGAATTCCCTGTAG-1_row76_col124_68um_histomicsT... -0.361780 -0.013016  ...
# TACCTCACCAATTGTA-1_row77_col125_68um_histomicsT...  0.013388  0.507437  ...
# AGTCGAATTAGCGTAA-1_row76_col126_68um_histomicsT... -0.022631 -0.108048  ...
# TTGAAGTGCATCTACA-1_row77_col127_68um_histomicsT... -0.237890  0.072982  ...
#
#                                                         1526      1527  \
# CCGACCACCCTACGCG_row0_col0_68um_histomicsTK_mac... -0.183785 -0.402442
# AAGCCATAGTCGCGAC_row1_col1_68um_histomicsTK_mac... -0.347054 -0.115743
# TTGGGCGGACCGAAGC_row0_col2_68um_histomicsTK_mac... -0.227530 -0.358827
# AGTAAAGCGCATAATC_row1_col3_68um_histomicsTK_mac... -0.447100 -0.521371
# CGACTCCGCCGATCAA_row0_col4_68um_histomicsTK_mac... -0.226925 -0.101395
# ...                                                      ...       ...
# GAACGTTTGTATCCAC-1_row77_col123_68um_histomicsT... -0.565600  0.117148
# ATTGAATTCCCTGTAG-1_row76_col124_68um_histomicsT... -0.059171  0.163159
# TACCTCACCAATTGTA-1_row77_col125_68um_histomicsT... -0.460070  0.271483
# AGTCGAATTAGCGTAA-1_row76_col126_68um_histomicsT... -0.189079 -0.104666
# TTGAAGTGCATCTACA-1_row77_col127_68um_histomicsT... -0.726628 -0.004906
#
#                                                         1528      1529  \
# CCGACCACCCTACGCG_row0_col0_68um_histomicsTK_mac... -0.029682 -0.346236
# AAGCCATAGTCGCGAC_row1_col1_68um_histomicsTK_mac... -0.238577  0.093472
# TTGGGCGGACCGAAGC_row0_col2_68um_histomicsTK_mac...  0.096895 -0.259203
# AGTAAAGCGCATAATC_row1_col3_68um_histomicsTK_mac...  0.678048 -0.042841
# CGACTCCGCCGATCAA_row0_col4_68um_histomicsTK_mac...  0.157453 -0.490854
# ...                                                      ...       ...
# GAACGTTTGTATCCAC-1_row77_col123_68um_histomicsT... -0.455262  0.134334
# ATTGAATTCCCTGTAG-1_row76_col124_68um_histomicsT...  0.021831  0.408173
# TACCTCACCAATTGTA-1_row77_col125_68um_histomicsT... -0.069067 -0.012664
# AGTCGAATTAGCGTAA-1_row76_col126_68um_histomicsT...  0.046133 -0.134130
# TTGAAGTGCATCTACA-1_row77_col127_68um_histomicsT...  0.308096 -0.255900
#
#                                                         1530      1531  \
# CCGACCACCCTACGCG_row0_col0_68um_histomicsTK_mac...  0.013579  0.101487
# AAGCCATAGTCGCGAC_row1_col1_68um_histomicsTK_mac...  0.027230  0.052773
# TTGGGCGGACCGAAGC_row0_col2_68um_histomicsTK_mac...  0.067773  0.164373
# AGTAAAGCGCATAATC_row1_col3_68um_histomicsTK_mac...  0.153587 -0.087965
# CGACTCCGCCGATCAA_row0_col4_68um_histomicsTK_mac...  0.055652  0.306610
# ...                                                      ...       ...
# GAACGTTTGTATCCAC-1_row77_col123_68um_histomicsT...  0.425124 -0.022367
# ATTGAATTCCCTGTAG-1_row76_col124_68um_histomicsT... -0.092569 -0.062143
# TACCTCACCAATTGTA-1_row77_col125_68um_histomicsT...  0.086282  0.199481
# AGTCGAATTAGCGTAA-1_row76_col126_68um_histomicsT...  0.211668 -0.283365
# TTGAAGTGCATCTACA-1_row77_col127_68um_histomicsT...  0.238081  0.653814
#
#                                                         1532      1533  \
# CCGACCACCCTACGCG_row0_col0_68um_histomicsTK_mac... -0.392896 -0.502757
# AAGCCATAGTCGCGAC_row1_col1_68um_histomicsTK_mac... -0.411942 -0.400563
# TTGGGCGGACCGAAGC_row0_col2_68um_histomicsTK_mac... -0.745350 -0.504894
# AGTAAAGCGCATAATC_row1_col3_68um_histomicsTK_mac... -0.506997 -0.796459
# CGACTCCGCCGATCAA_row0_col4_68um_histomicsTK_mac... -0.514799 -0.372846
# ...                                                      ...       ...
# GAACGTTTGTATCCAC-1_row77_col123_68um_histomicsT...  0.333482  0.351928
# ATTGAATTCCCTGTAG-1_row76_col124_68um_histomicsT...  0.336730 -0.066342
# TACCTCACCAATTGTA-1_row77_col125_68um_histomicsT...  0.292597 -0.213758
# AGTCGAATTAGCGTAA-1_row76_col126_68um_histomicsT...  0.365241 -0.074674
# TTGAAGTGCATCTACA-1_row77_col127_68um_histomicsT...  0.219668 -0.015935
#
#                                                         1534      1535
# CCGACCACCCTACGCG_row0_col0_68um_histomicsTK_mac...  0.070022  0.485976
# AAGCCATAGTCGCGAC_row1_col1_68um_histomicsTK_mac... -0.253814  0.072173
# TTGGGCGGACCGAAGC_row0_col2_68um_histomicsTK_mac... -0.006941  0.290454
# AGTAAAGCGCATAATC_row1_col3_68um_histomicsTK_mac... -0.282675  0.026572
# CGACTCCGCCGATCAA_row0_col4_68um_histomicsTK_mac...  0.017713  0.286025
# ...                                                      ...       ...
# GAACGTTTGTATCCAC-1_row77_col123_68um_histomicsT... -0.037596 -0.066711
# ATTGAATTCCCTGTAG-1_row76_col124_68um_histomicsT... -0.308147 -0.091009
# TACCTCACCAATTGTA-1_row77_col125_68um_histomicsT... -0.075924 -0.252125
# AGTCGAATTAGCGTAA-1_row76_col126_68um_histomicsT... -0.144594  0.196428
# TTGAAGTGCATCTACA-1_row77_col127_68um_histomicsT...  0.334041 -0.477147
#
# [8529 rows x 1536 columns]

# %% [markdown]
# # 2. - Dimensionality reduction

# %% [markdown]
# Let's plot the cumulative variance explained by the most important components.

# %% [markdown]
# ## 2.1 - For 100 μm tiles

# %%
from utils_clust_n_class import pca_cumulative_variance_plot

plot = pca_cumulative_variance_plot(merged_selected_pickle_df_100um, normalisation_name, TILE_SIZE)
plot.show()

# %% [markdown]
# Then let's have a quick visualisation of the PCA, UMAP and tSNE plots.

# %%
from utils_clust_n_class import all_dim_red

COLORS_FOR_SPATIALS = {"Spatial ATAC": "lightcoral", "Visium ST": "lightsteelblue"}

plot_100, dim_red_results_100 =  all_dim_red(merged_selected_pickle_df_100um, normalisation_name, COLORS_FOR_SPATIALS, TILE_SIZE, selected_methods = ["PCA", "ICA", "tSNE"])
plot_100.show()
# Out:
# /disk2/work/gabgam/gigi_env/the_project/4_clustering_and_classification/utils_clust_n_class.py:159: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(result[:, 0], result[:, 1], c=colors, s=4, cmap='coolwarm')
# /disk2/work/gabgam/gigi_env/the_project/4_clustering_and_classification/utils_clust_n_class.py:159: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(result[:, 0], result[:, 1], c=colors, s=4, cmap='coolwarm')
# /disk2/work/gabgam/gigi_env/the_project/4_clustering_and_classification/utils_clust_n_class.py:159: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(result[:, 0], result[:, 1], c=colors, s=4, cmap='coolwarm')

# %%
plot_100.savefig(os.path.join(PATH_TO_FIGURES, f"plot_all_dimensionality_reductions_{TILE_SIZE}um_{normalisation_name.replace(' ', '_')}.pdf"),
                format="PDF", bbox_inches='tight')

# %% [markdown]
# So, we can say that the normalisation is necessary.

# %% [markdown]
# ---
#
# ## 2.2 - For 68 μm tiles

# %%
from utils_clust_n_class import pca_cumulative_variance_plot

plot = pca_cumulative_variance_plot(merged_selected_pickle_df_68um, normalisation_name, SPOT_SIZE)
plot.show()

# %% [markdown]
# Then let's have a quick visualisation of the PCA, UMAP and tSNE plots.

# %%
from utils_clust_n_class import all_dim_red

COLORS_FOR_SPATIALS = {"Spatial ATAC": "lightcoral", "Visium ST": "lightsteelblue"}

plot_68, dim_red_results_68 =  all_dim_red(merged_selected_pickle_df_68um, normalisation_name, COLORS_FOR_SPATIALS, SPOT_SIZE, selected_methods = ["PCA", "ICA", "tSNE"])
plot_68.show()
# Out:
# /disk2/work/gabgam/gigi_env/the_project/4_clustering_and_classification/utils_clust_n_class.py:159: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(result[:, 0], result[:, 1], c=colors, s=4, cmap='coolwarm')
# /disk2/work/gabgam/gigi_env/the_project/4_clustering_and_classification/utils_clust_n_class.py:159: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(result[:, 0], result[:, 1], c=colors, s=4, cmap='coolwarm')
# /disk2/work/gabgam/gigi_env/the_project/4_clustering_and_classification/utils_clust_n_class.py:159: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(result[:, 0], result[:, 1], c=colors, s=4, cmap='coolwarm')

# %%
plot_68.savefig(os.path.join(PATH_TO_FIGURES, f"plot_all_dimensionality_reductions_{SPOT_SIZE}um_{normalisation_name.replace(' ', '_')}.pdf"), 
                format="PDF", bbox_inches='tight')

# %% [markdown]
# So, we can say that the normalisation is necessary.

# %% [markdown]
# ---

# %% [markdown]
# ## 3.2 Spectral Clustering

# %% [markdown]
# When we talk about “affinity”, we are essentially referring to how similar two points are to each other. In practical terms, affinity determines how close or similar points are in a multidimensional space. The more similar two points are, the greater the value of the affinity between them, and vice versa.
#
# In the context of spectral clustering, there are several methods to calculate affinity. Some of the main methods are:
#
# -   **Nearest Neighbors**: The affinity between points is calculated based on the Euclidean distance or a distance metric defined between the closest points.
# -   **RBF (Radial Basis Function)**: Affinity is calculated using a Gaussian radial function, which measures the distance between points in feature space.
# -   **Precomputed**: Allows you to provide a precomputed similarity or dissimilarity matrix between points.
# -   **KNN (K-Nearest Neighbors)**: Uses the similarity between the k-nearest points as affinity.

# %% [markdown]
# # 4. Clustering

# %%
import math
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering, HDBSCAN, MeanShift, estimate_bandwidth, SpectralClustering, AffinityPropagation, Birch
from sklearn.mixture import GaussianMixture


clustering_methods = [
    ("K-Means", KMeans(n_clusters=5, random_state=123)),
    ("Spectral Clustering", SpectralClustering(n_clusters=5, affinity='nearest_neighbors', n_neighbors=10, 
                                               eigen_solver='arpack', random_state=123)),
    ("MeanShift", MeanShift()),  # bandwidth will be estimated later
    ("DBSCAN", DBSCAN(eps=0.5, min_samples=20)),
    ("HDBSCAN", HDBSCAN(min_cluster_size=20)),
    ("Agglomerative", AgglomerativeClustering(n_clusters=5, metric='euclidean', linkage='ward')),
    ("Affinity Propagation", AffinityPropagation(preference=-50)),  # Adjust preference as needed
    ("Birch", Birch(threshold=0.5, n_clusters=5)),  # Adjust threshold as needed
    ("Gaussian Mixture", GaussianMixture(n_components=5, random_state=123))
]

n_methods = len(clustering_methods)
rows = 2
cols = math.ceil(n_methods / rows)

for tech in dim_red_results.keys():
    fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 5), constrained_layout=True)
    
    for i, (method_name, model) in enumerate(clustering_methods):
        # Estimate bandwidth if using MeanShift
        if method_name == "MeanShift":
            est_band = estimate_bandwidth(dim_red_results[tech])
            model.set_params(bandwidth=est_band)
        
        

        # Compute row and col indices
        row, col = divmod(i, cols)
        
        # Fit the clustering model and predict labels
        cluster_labels = model.fit_predict(dim_red_results[tech])
        
        # Plot in the appropriate subplot
        ax = axes[row, col]  # Access subplot by row and column
        scatter = ax.scatter(dim_red_results[tech][:, 0], dim_red_results[tech][:, 1], c=cluster_labels, s=5, cmap='tab10')
        ax.set_title(f"{tech} Projection with {method_name} Clustering")
        ax.set_xlabel(f'{method_name} Component 1')
        ax.set_ylabel(f'{method_name} Component 2')
    
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 23
#      20 rows = 2
#      21 cols = math.ceil(n_methods / rows)
# ---> 23 for tech in dim_red_results.keys():
#      24     fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 5), constrained_layout=True)
#      26     for i, (method_name, model) in enumerate(clustering_methods):
#      27         # Estimate bandwidth if using MeanShift
#
# NameError: name 'dim_red_results' is not defined

# %%
from sklearn.cluster import SpectralClustering
from sklearn.datasets import make_blobs

# Generate sample data
X, _ = make_blobs(n_samples=100, centers=3, cluster_std=0.60, random_state=0)

# Apply Spectral Clustering
sc = SpectralClustering(n_clusters=3, affinity='nearest_neighbors', n_init=100)
labels = sc.fit_predict(X)

print("Cluster labels:", labels)
