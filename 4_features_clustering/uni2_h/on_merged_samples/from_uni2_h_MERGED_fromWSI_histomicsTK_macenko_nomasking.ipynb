# %% [markdown]
# Clustering of features extracted from tiles with UNI2.\
# TILES: normalised at WSI level with HistomicsTK Macenko's method without masking\
# Conda environment: `cluster_n_class`.

# %% [markdown]
# ---
# # 0. - Imports and paths

# %%
import os
import pandas as pd
import matplotlib.font_manager as fm
# %matplotlib inline
import matplotlib.pyplot as plt
import pickle
import matplotlib.image as mpimg
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import seaborn as sns
from PIL import Image, ImageDraw
import numpy as np
import re
from collections import defaultdict
import matplotlib.pyplot as plt
from sklearn.cluster import FeatureAgglomeration
from sklearn.decomposition import PCA#, TruncatedSVD
#import umap
import umap.umap_ as umap
from sklearn.manifold import TSNE
from matplotlib.lines import Line2D

# %%
os.chdir("/disk2/user/gabgam/the_project/4_features_clustering/")
print(os.getcwd())
# Out:
# /disk2/user/gabgam/the_project/4_features_clustering

# %%
# Fetch DM Sans font file from https://github.com/google/fonts/blob/main/ofl/dmsans/DMSans%5Bopsz%2Cwght%5D.ttf or, better, https://fonts.google.com/specimen/DM+Sans
font_path = "../fonts/static/DMSans-Medium.ttf" 

# Add font to matplotlib
try:
    fm.fontManager.addfont(font_path)
    plt.rcParams['font.family'] = 'DM Sans'
except RuntimeError as e:
    print(f"Failed to load font: {e}")

# %%
model = "UNI2-h"

# %%
# PATH_TO_MERGED_PICKLES = f"output/{model}/satac_C1_v3_allspots_&_visium_2022_FF_WG_10X_img_not_changed_allspots/"
# COMPARISON = "satac_C1_v3_allspots_&_visium_2022_FF_WG_10X_img_not_changed_allspots"

# SELECTED_PICKLE_100um = 'MERGED_satac_C1_&_v3_allspots__&__visium_2022_FF_WG_10X_&_img_not_changed_allspots__for__target_is_reference_full_100um_fromWSI_histomicsTK_macenko_nomasking.pickle'
# SELECTED_PICKLE_68um = 'MERGED_satac_C1_&_v3_allspots__&__visium_2022_FF_WG_10X_&_img_not_changed_allspots__for__target_is_reference_full_68um_fromWSI_histomicsTK_macenko_nomasking.pickle'

# %%
PATH_TO_MERGED_PICKLES = f"output/{model}/satac_C1_v3_allspots_&_visium_FFPE_dcis_idc_10X_img_not_changed_allspots/"
COMPARISON = "satac_C1_v3_allspots_&_visium_FFPE_dcis_idc_10X_img_not_changed_allspots"

SELECTED_PICKLE_100um = 'MERGED_satac_C1_&_v3_allspots__&__visium_FFPE_dcis_idc_10X_&_img_not_changed_allspots__for__target_is_reference_full_100um_fromWSI_histomicsTK_macenko_nomasking.pickle'
SELECTED_PICKLE_68um = 'MERGED_satac_C1_&_v3_allspots__&__visium_FFPE_dcis_idc_10X_&_img_not_changed_allspots__for__target_is_reference_full_68um_fromWSI_histomicsTK_macenko_nomasking.pickle'

# %%
# path to the target image
PATH_TO_REFERENCE = "../2_image_normalisation/reference_images/reference_full.jpeg"
# `TARGET_IS_<filename>`
TARGET_IS = "target_is_reference_full"

# %% [markdown]
# Defining the path to the figures.

# %%
PATH_TO_FIGURES = f"figures/{model}/{COMPARISON}"
os.makedirs(PATH_TO_FIGURES, exist_ok=True)

# %% [markdown]
# # 1. - Importing the extracted features

# %% [markdown]
# First of all, let's see all the MERGED `.pickle` files inside the folder of the saved features.

# %%
all_pickle_names = [i for i in os.listdir(PATH_TO_MERGED_PICKLES) if i.endswith('.pickle')]

print(f"{len(all_pickle_names)} .pickle files inside the folder.\n")
print(all_pickle_names)
# Out:
# 8 .pickle files inside the folder.
#
# ['MERGED_satac_C1_&_v3_allspots__&__visium_FFPE_dcis_idc_10X_&_img_not_changed_allspots__for__target_is_reference_full_100um_ORIGINAL WSI.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_FFPE_dcis_idc_10X_&_img_not_changed_allspots__for__target_is_reference_full_100um_fromWSI_histomicsTK_macenko_nomasking.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_FFPE_dcis_idc_10X_&_img_not_changed_allspots__for__target_is_reference_full_100um_histomicsTK_macenko_nomasking.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_FFPE_dcis_idc_10X_&_img_not_changed_allspots__for__target_is_reference_full_100um_stainNET.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_FFPE_dcis_idc_10X_&_img_not_changed_allspots__for__target_is_reference_full_68um_ORIGINAL WSI.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_FFPE_dcis_idc_10X_&_img_not_changed_allspots__for__target_is_reference_full_68um_fromWSI_histomicsTK_macenko_nomasking.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_FFPE_dcis_idc_10X_&_img_not_changed_allspots__for__target_is_reference_full_68um_histomicsTK_macenko_nomasking.pickle', 'MERGED_satac_C1_&_v3_allspots__&__visium_FFPE_dcis_idc_10X_&_img_not_changed_allspots__for__target_is_reference_full_68um_stainNET.pickle']

# %% [markdown]
# And let's choose the first file to visualise and extract the normalisation name from it.

# %%
TILE_SIZE = 100
SPOT_SIZE = 68

# Extractin the normalisation name from just one of it. They are the same in the end
# Find the pattern matching "<number>um_", the normalisation name is after it.
match = re.search(r"\d+um_", SELECTED_PICKLE_100um)

if match:
    # Extract everything after "<number>um_", remove the file type name and replace eventually present underscores with spaces.
    normalisation_name = SELECTED_PICKLE_100um.split(match.group())[-1].split(".")[0].replace("_", " ")
else:
    print("Wrong file inserted, no normalisation name found.")

print(normalisation_name)
# Out:
# fromWSI histomicsTK macenko nomasking

# %%
from utils_clust_n_class import load_pickle_as_df

merged_selected_pickle_df_100um = load_pickle_as_df(os.path.join(PATH_TO_MERGED_PICKLES, SELECTED_PICKLE_100um))
merged_selected_pickle_df_100um
# Out:
#                                                         0         1     \
# CCGACCACCCTACGCG_row0_col0_100um_fromWSI_histom...  0.306647  0.593232
# AAGCCATAGTCGCGAC_row1_col1_100um_fromWSI_histom... -0.277310  0.271517
# TTGGGCGGACCGAAGC_row0_col2_100um_fromWSI_histom... -0.010810  0.500611
# AGTAAAGCGCATAATC_row1_col3_100um_fromWSI_histom... -0.204490  0.421389
# CGACTCCGCCGATCAA_row0_col4_100um_fromWSI_histom... -0.101863  0.157513
# ...                                                      ...       ...
# GCCCTGAGGATGGGCT-1_row68_col74_100um_fromWSI_hi... -0.025844 -0.310275
# CGGGCGATGGATCACG-1_row69_col75_100um_fromWSI_hi...  0.718692 -0.429556
# TGCGGACTTGACTCCG-1_row68_col76_100um_fromWSI_hi...  0.630683  0.079332
# TCGCTGCCAATGCTGT-1_row68_col80_100um_fromWSI_hi...  0.165015 -0.279974
# GGTGTAGGTAAGTAAA-1_row70_col50_100um_fromWSI_hi...  0.472641  0.158793
#
#                                                         2         3     \
# CCGACCACCCTACGCG_row0_col0_100um_fromWSI_histom...  0.131164  0.008067
# AAGCCATAGTCGCGAC_row1_col1_100um_fromWSI_histom...  0.192413  0.119113
# TTGGGCGGACCGAAGC_row0_col2_100um_fromWSI_histom...  0.032030 -0.002228
# AGTAAAGCGCATAATC_row1_col3_100um_fromWSI_histom...  0.213300 -0.014385
# CGACTCCGCCGATCAA_row0_col4_100um_fromWSI_histom...  0.102426  0.029608
# ...                                                      ...       ...
# GCCCTGAGGATGGGCT-1_row68_col74_100um_fromWSI_hi... -0.222745 -0.098028
# CGGGCGATGGATCACG-1_row69_col75_100um_fromWSI_hi...  0.417421 -0.229247
# TGCGGACTTGACTCCG-1_row68_col76_100um_fromWSI_hi...  0.003376 -0.230353
# TCGCTGCCAATGCTGT-1_row68_col80_100um_fromWSI_hi...  0.236617 -0.390857
# GGTGTAGGTAAGTAAA-1_row70_col50_100um_fromWSI_hi... -0.271205 -0.320132
#
#                                                         4         5     \
# CCGACCACCCTACGCG_row0_col0_100um_fromWSI_histom...  0.131873 -0.304478
# AAGCCATAGTCGCGAC_row1_col1_100um_fromWSI_histom...  0.071954 -0.536523
# TTGGGCGGACCGAAGC_row0_col2_100um_fromWSI_histom...  0.055893 -0.718580
# AGTAAAGCGCATAATC_row1_col3_100um_fromWSI_histom...  0.182819 -0.237814
# CGACTCCGCCGATCAA_row0_col4_100um_fromWSI_histom...  0.161711 -0.521121
# ...                                                      ...       ...
# GCCCTGAGGATGGGCT-1_row68_col74_100um_fromWSI_hi... -0.143694 -0.411475
# CGGGCGATGGATCACG-1_row69_col75_100um_fromWSI_hi... -0.064497 -0.069957
# TGCGGACTTGACTCCG-1_row68_col76_100um_fromWSI_hi...  0.109620 -0.670134
# TCGCTGCCAATGCTGT-1_row68_col80_100um_fromWSI_hi... -0.273142 -0.708889
# GGTGTAGGTAAGTAAA-1_row70_col50_100um_fromWSI_hi... -0
# TTGGGCGGACCGAAGC_row0_col2_68um_fromWSI_histomi... -0.001038 -0.614350
# AGTAAAGCGCATAATC_row1_col3_68um_fromWSI_histomi...  0.053233 -0.080037
# CGACTCCGCCGATCAA_row0_col4_68um_fromWSI_histomi...  0.018006 -0.287292
# ...                                                      ...       ...
# GCCCTGAGGATGGGCT-1_row68_col74_68um_fromWSI_his...  0.022989 -0.353819
# CGGGCGATGGATCACG-1_row69_col75_68um_fromWSI_his... -0.113084  0.275144
# TGCGGACTTGACTCCG-1_row68_col76_68um_fromWSI_his... -0.023432 -0.311007
# TCGCTGCCAATGCTGT-1_row68_col80_68um_fromWSI_his... -0.190528 -0.366721
# GGTGTAGGTAAGTAAA-1_row70_col50_68um_fromWSI_his...  0.018284 -0.434884
#
#                                                         6         7     \
# CCGACCACCCTACGCG_row0_col0_68um_fromWSI_histomi...  0.246074 -0.821029
# AAGCCATAGTCGCGAC_row1_col1_68um_fromWSI_histomi... -0.011937 -0.455187
# TTGGGCGGACCGAAGC_row0_col2_68um_fromWSI_histomi... -0.033597 -0.552375
# AGTAAAGCGCATAATC_row1_col3_68um_fromWSI_histomi...  0.053527 -0.761466
# CGACTCCGCCGATCAA_row0_col4_68um_fromWSI_histomi... -0.063921 -0.569975
# ...                                                      ...       ...
# GCCCTGAGGATGGGCT-1_row68_col74_68um_fromWSI_his... -0.044332 -0.144523
# CGGGCGATGGATCACG-1_row69_col75_68um_fromWSI_his...  0.178670 -0.667597
# TGCGGACTTGACTCCG-1_row68_col76_68um_fromWSI_his... -0.258985 -0.249178
# TCGCTGCCAATGCTGT-1_row68_col80_68um_fromWSI_his...  0.121500 -0.141022
# GGTGTAGGTAAGTAAA-1_row70_col50_68um_fromWSI_his...  0.133938 -0.302624
#
#                                                         8         9     ...  \
# CCGACCACCCTACGCG_row0_col0_68um_fromWSI_histomi...  0.323336  0.322580  ...
# AAGCCATAGTCGCGAC_row1_col1_68um_fromWSI_histomi...  0.110391  0.240178  ...
# TTGGGCGGACCGAAGC_row0_col2_68um_fromWSI_histomi...  0.436913  0.132012  ...
# AGTAAAGCGCATAATC_row1_col3_68um_fromWSI_histomi...  0.358641  0.096303  ...
# CGACTCCGCCGATCAA_row0_col4_68um_fromWSI_histomi...  0.139109  0.461400  ...
# ...                                                      ...       ...  ...
# GCCCTGAGGATGGGCT-1_row68_col74_68um_fromWSI_his...  0.126236  0.064211  ...
# CGGGCGATGGATCACG-1_row69_col75_68um_fromWSI_his... -0.028243  0.468442  ...
# TGCGGACTTGACTCCG-1_row68_col76_68um_fromWSI_his... -0.073253  0.157126  ...
# TCGCTGCCAATGCTGT-1_row68_col80_68um_fromWSI_his... -0.064947  0.180117  ...
# GGTGTAGGTAAGTAAA-1_row70_col50_68um_fromWSI_his... -0.587323  0.077405  ...
#
#                                                         1526      1527  \
# CCGACCACCCTACGCG_row0_col0_68um_fromWSI_histomi... -0.020540 -0.532607
# AAGCCATAGTCGCGAC_row1_col1_68um_fromWSI_histomi... -0.261791 -0.280404
# TTGGGCGGACCGAAGC_row0_col2_68um_fromWSI_histomi... -0.067796 -0.317546
# AGTAAAGCGCATAATC_row1_col3_68um_fromWSI_histomi... -0.484724 -0.498325
# CGACTCCGCCGATCAA_row0_col4_68um_fromWSI_histomi... -0.173706 -0.138895
# ...                                                      ...       ...
# GCCCTGAGGATGGGCT-1_row68_col74_68um_fromWSI_his... -0.400419 -0.153111
# CGGGCGATGGATCACG-1_row69_col75_68um_fromWSI_his... -0.263399  0.405255
# TGCGGACTTGACTCCG-1_row68_col76_68um_fromWSI_his... -0.575805  0.141143
# TCGCTGCCAATGCTGT-1_row68_col80_68um_fromWSI_his...  0.042852  0.017226
# GGTGTAGGTAAGTAAA-1_row70_col50_68um_fromWSI_his... -0.333837 -0.140396
#
#                                                         1528      1529  \
# CCGACCACCCTACGCG_row0_col0_68um_fromWSI_histomi... -0.041408 -0.315366
# AAGCCATAGTCGCGAC_row1_col1_68um_fromWSI_histomi... -0.243525  0.404581
# TTGGGCGGACCGAAGC_row0_col2_68um_fromWSI_histomi...  0.240616  0.033644
# AGTAAAGCGCATAATC_row1_col3_68um_fromWSI_histomi...  0.667193  0.209527
# CGACTCCGCCGATCAA_row0_col4_68um_fromWSI_histomi...  0.106425 -0.234276
# ...                                                      ...       ...
# GCCCTGAGGATGGGCT-1_row68_col74_68um_fromWSI_his...  0.202645 -0.268763
# CGGGCGATGGATCACG-1_row69_col75_68um_fromWSI_his... -0.208887  0.047407
# TGCGGACTTGACTCCG-1_row68_col76_68um_fromWSI_his... -0.010835  0.239083
# TCGCTGCCAATGCTGT-1_row68_col80_68um_fromWSI_his... -0.145955  0.272930
# GGTGTAGGTAAGTAAA-1_row70_col50_68um_fromWSI_his...  0.149907  0.425785
#
#                                                         1530      1531  \
# CCGACCACCCTACGCG_row0_col0_68um_fromWSI_histomi... -0.056752  0.102264
# AAGCCATAGTCGCGAC_row1_col1_68um_fromWSI_histomi...  0.023575  0.067011
# TTGGGCGGACCGAAGC_row0_col2_68um_fromWSI_histomi...  0.079122  0.253433
# AGTAAAGCGCATAATC_row1_col3_68um_fromWSI_histomi...  0.106198 -0.164751
# CGACTCCGCCGATCAA_row0_col4_68um_fromWSI_histomi...  0.051205  0.247195
# ...                                                      ...       ...
# GCCCTGAGGATGGGCT-1_row68_col74_68um_fromWSI_his...  0.139954 -0.140879
# CGGGCGATGGATCACG-1_row69_col75_68um_fromWSI_his... -0.037033 -0.282129
# TGCGGACTTGACTCCG-1_row68_col76_68um_fromWSI_his...  0.101091 -0.503155
# TCGCTGCCAATGCTGT-1_row68_col80_68um_fromWSI_his...  0.496417 -0.220175
# GGTGTAGGTAAGTAAA-1_row70_col50_68um_fromWSI_his...  0.037327  0.024996
#
#                                                         1532      1533  \
# CCGACCACCCTACGCG_row0_col0_68um_fromWSI_histomi... -0.374271 -0.488459
# AAGCCATAGTCGCGAC_row1_col1_68um_fromWSI_histomi... -0.445747 -0.402422
# TTGGGCGGACCGAAGC_row0_col2_68um_fromWSI_histomi... -0.760766 -0.527430
# AGTAAAGCGCATAATC_row1_col3_68um_fromWSI_histomi... -0.597724 -0.810864
# CGACTCCGCCGATCAA_row0_col4_68um_fromWSI_histomi... -0.551678 -0.171714
# ...                                                      ...       ...
# GCCCTGAGGATGGGCT-1_row68_col74_68um_fromWSI_his...  0.050088  0.130922
# CGGGCGATGGATCACG-1_row69_col75_68um_fromWSI_his...  0.023539 -0.176585
# TGCGGACTTGACTCCG-1_row68_col76_68um_fromWSI_his... -0.000887  0.100993
# TCGCTGCCAATGCTGT-1_row68_col80_68um_fromWSI_his...  0.343613 -0.478352
# GGTGTAGGTAAGTAAA-1_row70_col50_68um_fromWSI_his... -0.119590 -0.634056
#
#                                                         1534      1535
# CCGACCACCCTACGCG_row0_col0_68um_fromWSI_histomi...  0.088094  0.581046
# AAGCCATAGTCGCGAC_row1_col1_68um_fromWSI_histomi... -0.361169  0.123328
# TTGGGCGGACCGAAGC_row0_col2_68um_fromWSI_histomi... -0.076690  0.200313
# AGTAAAGCGCATAATC_row1_col3_68um_fromWSI_histomi... -0.280679  0.104281
# CGACTCCGCCGATCAA_row0_col4_68um_fromWSI_histomi...  0.123789  0.344395
# ...                                                      ...       ...
# GCCCTGAGGATGGGCT-1_row68_col74_68um_fromWSI_his...  0.088239 -0.498846
# CGGGCGATGGATCACG-1_row69_col75_68um_fromWSI_his... -0.152120  0.034181
# TGCGGACTTGACTCCG-1_row68_col76_68um_fromWSI_his...  0.309396 -0.161223
# TCGCTGCCAATGCTGT-1_row68_col80_68um_fromWSI_his... -0.278843 -0.131305
# GGTGTAGGTAAGTAAA-1_row70_col50_68um_fromWSI_his... -0.607855  0.029731
#
# [6149 rows x 1536 columns]

# %% [markdown]
# # 2. - Dimensionality reduction

# %% [markdown]
# Let's plot the cumulative variance explained by the most important components.

# %% [markdown]
# ## 2.1 - For 100 μm tiles

# %%
from utils_clust_n_class import pca_cumulative_variance_plot

plot = pca_cumulative_variance_plot(merged_selected_pickle_df_100um, normalisation_name, TILE_SIZE, n_comp = 200)
plot.show()

# %% [markdown]
# Then let's have a quick visualisation of the PCA, UMAP and tSNE plots.

# %%
from utils_clust_n_class import all_dim_red

COLORS_FOR_SPATIALS = {"Spatial ATAC": "lightcoral", "Visium ST": "lightsteelblue"}

plot_100, dim_red_results_100 =  all_dim_red(merged_selected_pickle_df_100um, normalisation_name, COLORS_FOR_SPATIALS, TILE_SIZE, selected_methods = ["PCA", "ICA"], n_comp = 200)
plot_100.show()
# Out:
# /disk2/user/gabgam/the_project/4_features_clustering/utils_clust_n_class.py:127: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(result[:, 0], result[:, 1], c=colors, s=4, cmap='coolwarm')
# /disk2/user/gabgam/the_project/4_features_clustering/utils_clust_n_class.py:127: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(result[:, 0], result[:, 1], c=colors, s=4, cmap='coolwarm')

# %%
plot_100.savefig(os.path.join(PATH_TO_FIGURES, f"plot_all_dimensionality_reductions_{TILE_SIZE}um_{normalisation_name.replace(' ', '_')}.pdf"),
                format="PDF", bbox_inches='tight')

# %% [markdown]
# So, we can say that the normalisation is necessary.

# %% [markdown]
# ---
#
# ## 2.2 - For 68 μm tiles

# %%
from utils_clust_n_class import pca_cumulative_variance_plot

plot = pca_cumulative_variance_plot(merged_selected_pickle_df_68um, normalisation_name, SPOT_SIZE, n_comp = 200)
plot.show()

# %% [markdown]
# Then let's have a quick visualisation of the PCA, UMAP and tSNE plots.

# %%
from utils_clust_n_class import all_dim_red

COLORS_FOR_SPATIALS = {"Spatial ATAC": "lightcoral", "Visium ST": "lightsteelblue"}

plot_68, dim_red_results_68 =  all_dim_red(merged_selected_pickle_df_68um, normalisation_name, COLORS_FOR_SPATIALS, SPOT_SIZE, selected_methods = ["PCA", "ICA"], n_comp = 200)
plot_68.show()
# Out:
# /disk2/user/gabgam/the_project/4_features_clustering/utils_clust_n_class.py:127: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(result[:, 0], result[:, 1], c=colors, s=4, cmap='coolwarm')
# /disk2/user/gabgam/the_project/4_features_clustering/utils_clust_n_class.py:127: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(result[:, 0], result[:, 1], c=colors, s=4, cmap='coolwarm')

# %%
plot_68.savefig(os.path.join(PATH_TO_FIGURES, f"plot_all_dimensionality_reductions_{SPOT_SIZE}um_{normalisation_name.replace(' ', '_')}.pdf"), 
                format="PDF", bbox_inches='tight')

# %% [markdown]
# So, we can say that the normalisation is not necessary.
